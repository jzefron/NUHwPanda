# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "Resources/Resources/schools_complete.csv"
student_data_to_load = "Resources/Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
school_data.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
student_data.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
#Calculate the total number of schools
tot_schools = len(school_data)

# %%
#Calculate the total number of schools
tot_students = len(student_data)

# %%
#Calculate the total budget
tot_budget = school_data['budget'].sum()
#tot_budget

# %%
#Calculate the average math score
ave_math_score = student_data['math_score'].mean()
#round(ave_math_score,1)

# %%
#Calculate the average reading score
ave_reading_score = student_data['reading_score'].mean()
#round(ave_reading_score,1)

# %%
#Calculate the percentage of students with a passing math score (70 or greater)
tot_math_pass = len(student_data.loc[student_data['math_score']>=70])
per_math_pass = tot_math_pass/tot_students
#round(per_math_pass*100)

# %%
#Calculate the percentage of students with a passing reading score (70 or greater)
tot_reading_pass = len(student_data.loc[student_data['reading_score']>=70])
per_reading_pass = tot_reading_pass/tot_students

#round(per_reading_pass*100)

# %%
df = pd.DataFrame({
    'Total Students':[tot_students],
    'Total Schools':[tot_schools],
    'Average Math Score':[ave_math_score],
    'Average Reading Score':[ave_reading_score],
  
    'Percentage Passing Math':[100* per_math_pass],
    'Percentage Passing Reading':[100*per_reading_pass],
      'Average Passing Rate':[50*(per_math_pass+per_reading_pass)]
    
})
#df.reindex(labels=['Total District'])
df['Total Students'] = df['Total Students'].map("{:,}".format)
df['Average Math Score'] = df['Average Math Score'].map("{:.1f}".format)
df['Average Reading Score'] = df['Average Reading Score'].map("{:.1f}".format)
df['Average Passing Rate'] =  df['Average Passing Rate'].map("{:.1f}".format)
df['Percentage Passing Math'] =df['Percentage Passing Math'].map("{:.0f}%".format)
df['Percentage Passing Reading'] =df['Percentage Passing Reading'].map("{:.0f}%".format)
df
# Out:
#   Total Students  Total Schools Average Math Score Average Reading Score  \
# 0         39,170             15               79.0                  81.9
#
#   Percentage Passing Math Percentage Passing Reading Average Passing Rate
# 0                     75%                        86%                 80.4

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# * Create a dataframe to hold the above results

# %%
student_mean = student_data.groupby(['school_name'])['reading_score','math_score'].mean()
student_mean.head(10)
# Out:
#                        reading_score  math_score
# school_name
# Bailey High School         81.033963   77.048432
# Cabrera High School        83.975780   83.061895
# Figueroa High School       81.158020   76.711767
# Ford High School           80.746258   77.102592
# Griffin High School        83.816757   83.351499
# Hernandez High School      80.934412   77.289752
# Holden High School         83.814988   83.803279
# Huang High School          81.182722   76.629414
# Johnson High School        80.966394   77.072464
# Pena High School           84.044699   83.839917

# %%
sd_pass_math = school_data_complete.loc[ school_data_complete['math_score']>=70]

mp= sd_pass_math.groupby('school_name').count()[['math_score']]
sd_pass_read = school_data_complete.loc[ school_data_complete['reading_score']>=70]
rp= sd_pass_read.groupby('school_name').count()[['reading_score']]
#school_data_complete['reading_pass']= school_data_complete['reading_score']>=70

#school_data_gb =school_data_complete.groupby(['school_name'])
#school_data_complete.loc[school_]
mp
# Out:
#                        math_score
# school_name
# Bailey High School           3318
# Cabrera High School          1749
# Figueroa High School         1946
# Ford High School             1871
# Griffin High School          1371
# Hernandez High School        3094
# Holden High School            395
# Huang High School            1916
# Johnson High School          3145
# Pena High School              910
# Rodriguez High School        2654
# Shelton High School          1653
# Thomas High School           1525
# Wilson High School           2143
# Wright High School           1680

# %%
#school_data_cons_m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-652bb2299dce> in <module>()
# ----> 1 school_data_cons_m
#
# NameError: name 'school_data_cons_m' is not defined

# %%
school_data.head()
school_data_cons = school_data[['school_name','type','size','budget']]
school_data_cons['Per Student Funding']= school_data['budget']/school_data['size']
#school_data_cons['Average Math Score'] = student_data.groupby(['school_name']).mean()['math_score']
school_data_cons_m = pd.merge(school_data_cons,student_mean, how="left", on=["school_name", "school_name"])
school_data_cons_m  = school_data_cons_m.rename(columns={'math_score':'Average Math Score',
                                                         'reading_score':'Average Reading Score'
                                                         })
#school_data_cons_m['math_pass'] =mp['math_pass']
school_data_cons_m= school_data_cons_m.merge(mp,how='left',on=['school_name','school_name'])#,right_index= True)
school_data_cons_m= school_data_cons_m.merge(rp,how='left',on=['school_name','school_name'])#,right_index= True)
school_data_cons_m['Percentage Math Pass'] = school_data_cons_m['math_score']/school_data_cons_m['size']*100
school_data_cons_m['Percentage Reading Pass'] = school_data_cons_m['reading_score']/school_data_cons_m['size']*100
school_data_cons_m['Percentage Overall Pass'] = (school_data_cons_m['Percentage Math Pass'] + \
                                                school_data_cons_m['Percentage Reading Pass'])*0.5
school_data_cons_m =school_data_cons_m.drop(columns=['math_score','reading_score'])
sch_d_cons_unf = school_data_cons_m
school_data_cons_m['budget'] = school_data_cons_m['budget'].map("${:,}".format)
school_data_cons_m['Per Student Funding'] = school_data_cons_m['Per Student Funding'].map("${:.0f}".format)
school_data_cons_m['Average Reading Score'] =school_data_cons_m['Average Reading Score'].map("{:.1f}".format)
school_data_cons_m['Average Math Score'] =school_data_cons_m['Average Math Score'].map("{:.1f}".format)
school_data_cons_m['Percentage Reading Pass'] =school_data_cons_m['Percentage Reading Pass'].map("{:.1f}%".format)
school_data_cons_m['Percentage Math Pass'] =school_data_cons_m['Percentage Math Pass'].map("{:.1f}%".format)
school_data_cons_m['Percentage Overall Pass'] =school_data_cons_m['Percentage Overall Pass'].map("{:.1f}%".format)
school_data_cons_m =school_data_cons_m.set_index('school_name')
school_data_cons_m
# Out:
#                            type  size      budget Per Student Funding  \
# school_name
# Huang High School      District  2917  $1,910,635                $655
# Figueroa High School   District  2949  $1,884,411                $639
# Shelton High School     Charter  1761  $1,056,600                $600
# Hernandez High School  District  4635  $3,022,020                $652
# Griffin High School     Charter  1468    $917,500                $625
# Wilson High School      Charter  2283  $1,319,574                $578
# Cabrera High School     Charter  1858  $1,081,356                $582
# Bailey High School     District  4976  $3,124,928                $628
# Holden High School      Charter   427    $248,087                $581
# Pena High School        Charter   962    $585,858                $609
# Wright High School      Charter  1800  $1,049,400                $583
# Rodriguez High School  District  3999  $2,547,363                $637
# Johnson High School    District  4761  $3,094,650                $650
# Ford High School       District  2739  $1,763,916                $644
# Thomas High School      Charter  1635  $1,043,130                $638
#
#                       Average Reading Score Average Math Score  \
# school_name
# Huang High School                      81.2               76.6
# Figueroa High School                   81.2               76.7
# Shelton High School                    83.7               83.4
# Hernandez High School                  80.9               77.3
# Griffin High School                    83.8               83.4
# Wilson High School                     84.0               83.3
# Cabrera High School                    84.0               83.1
# Bailey High School                     81.0               77.0
# Holden High School                     83.8               83.8
# Pena High School                       84.0               83.8
# Wright High School                     84.0               83.7
# Rodriguez High School                  80.7               76.8
# Johnson High School                    81.0               77.1
# Ford High School                       80.7               77.1
# Thomas High School                     83.8               83.4
#
#                       Percentage Math Pass Percentage Reading Pass  \
# school_name
# Huang High School                    65.7%                   81.3%
# Figueroa High School                 66.0%                   80.7%
# Shelton High School                  93.9%                   95.9%
# Hernandez High School                66.8%                   80.9%
# Griffin High School                  93.4%                   97.1%
# Wilson High School                   93.9%                   96.5%
# Cabrera High School                  94.1%                   97.0%
# Bailey High School                   66.7%                   81.9%
# Holden High School                   92.5%                   96.3%
# Pena High School                     94.6%                   95.9%
# Wright High School                   93.3%                   96.6%
# Rodriguez High School                66.4%                   80.2%
# Johnson High School                  66.1%                   81.2%
# Ford High School                     68.3%                   79.3%
# Thomas High School                   93.3%                   97.3%
#
#                       Percentage Overall Pass
# school_name
# Huang High School                       73.5%
# Figueroa High School                    73.4%
# Shelton High School                     94.9%
# Hernandez High School                   73.8%
# Griffin High School                     95.3%
# Wilson High School                      95.2%
# Cabrera High School                     95.6%
# Bailey High School                      74.3%
# Holden High School                      94.4%
# Pena High School                        95.3%
# Wright High School                      95.0%
# Rodriguez High School                   73.3%
# Johnson High School                     73.6%
# Ford High School                        73.8%
# Thomas High School                      95.3%

# %% [markdown]
# ## Top Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the top five schools in overall passing rate

# %%
school_data_cons_m.sort_values('Percentage Overall Pass',ascending=False).head(5)
# Out:
#                         type  size      budget Per Student Funding  \
# school_name
# Cabrera High School  Charter  1858  $1,081,356                $582
# Griffin High School  Charter  1468    $917,500                $625
# Pena High School     Charter   962    $585,858                $609
# Thomas High School   Charter  1635  $1,043,130                $638
# Wilson High School   Charter  2283  $1,319,574                $578
#
#                     Average Reading Score Average Math Score  \
# school_name
# Cabrera High School                  84.0               83.1
# Griffin High School                  83.8               83.4
# Pena High School                     84.0               83.8
# Thomas High School                   83.8               83.4
# Wilson High School                   84.0               83.3
#
#                     Percentage Math Pass Percentage Reading Pass  \
# school_name
# Cabrera High School                94.1%                   97.0%
# Griffin High School                93.4%                   97.1%
# Pena High School                   94.6%                   95.9%
# Thomas High School                 93.3%                   97.3%
# Wilson High School                 93.9%                   96.5%
#
#                     Percentage Overall Pass
# school_name
# Cabrera High School                   95.6%
# Griffin High School                   95.3%
# Pena High School                      95.3%
# Thomas High School                    95.3%
# Wilson High School                    95.2%

# %% [markdown]
# ## Bottom Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the five worst-performing schools

# %%
school_data_cons_m.sort_values('Percentage Overall Pass',ascending=True).head(5)
# Out:
#                            type  size      budget Per Student Funding  \
# school_name
# Rodriguez High School  District  3999  $2,547,363                $637
# Figueroa High School   District  2949  $1,884,411                $639
# Huang High School      District  2917  $1,910,635                $655
# Johnson High School    District  4761  $3,094,650                $650
# Hernandez High School  District  4635  $3,022,020                $652
#
#                       Average Reading Score Average Math Score  \
# school_name
# Rodriguez High School                  80.7               76.8
# Figueroa High School                   81.2               76.7
# Huang High School                      81.2               76.6
# Johnson High School                    81.0               77.1
# Hernandez High School                  80.9               77.3
#
#                       Percentage Math Pass Percentage Reading Pass  \
# school_name
# Rodriguez High School                66.4%                   80.2%
# Figueroa High School                 66.0%                   80.7%
# Huang High School                    65.7%                   81.3%
# Johnson High School                  66.1%                   81.2%
# Hernandez High School                66.8%                   80.9%
#
#                       Percentage Overall Pass
# school_name
# Rodriguez High School                   73.3%
# Figueroa High School                    73.4%
# Huang High School                       73.5%
# Johnson High School                     73.6%
# Hernandez High School                   73.8%

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
school_data_complete['class']=pd.to_numeric(school_data_complete['grade'].str[:-2])
sch_by_grade =school_data_complete.groupby(['school_name','class'])
#sch_by_grade['class']=

sch_by_grade['math_score'].mean()
# Out:
# school_name            class
# Bailey High School     9        77.083676
#                        10       76.996772
#                        11       77.515588
#                        12       76.492218
# Cabrera High School    9        83.094697
#                        10       83.154506
#                        11       82.765560
#                        12       83.277487
# Figueroa High School   9        76.403037
#                        10       76.539974
#                        11       76.884344
#                        12       77.151369
# Ford High School       9        77.361345
#                        10       77.672316
#                        11       76.918058
#                        12       76.179963
# Griffin High School    9        82.044010
#                        10       84.229064
#                        11       83.842105
#                        12       83.356164
# Hernandez High School  9        77.438495
#                        10       77.337408
#                        11       77.136029
#                        12       77.186567
# Holden High School     9        83.787402
#                        10       83.429825
#                        11       85.000000
#                        12       82.855422
# Huang High School      9        77.027251
#                        10       75.908735
#                        11       76.446602
#                        12       77.225641
# Johnson High School    9        77.187857
#                        10       76.691117
#                        11       77.491653
#                        12       76.863248
# Pena High School       9        83.625455
#                        10       83.372000
#                        11       84.328125
#                        12       84.121547
# Rodriguez High School  9        76.859966
#                        10       76.612500
#                        11       76.395626
#                        12       77.690748
# Shelton High School    9        83.420755
#                        10       82.917411
#                        11       83.383495
#                        12       83.778976
# Thomas High School     9        83.590022
#                        10       83.087886
#                        11       83.498795
#                        12       83.497041
# Wilson High School     9        83.085578
#                        10       83.724422
#                        11       83.195326
#                        12       83.035794
# Wright High School     9        83.264706
#                        10       84.010288
#                        11       83.836782
#                        12       83.644986
# Name: math_score, dtype: float64

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
sch_by_grade['reading_score'].mean()
# Out:
# school_name            class
# Bailey High School     9        81.303155
#                        10       80.907183
#                        11       80.945643
#                        12       80.912451
# Cabrera High School    9        83.676136
#                        10       84.253219
#                        11       83.788382
#                        12       84.287958
# Figueroa High School   9        81.198598
#                        10       81.408912
#                        11       80.640339
#                        12       81.384863
# Ford High School       9        80.632653
#                        10       81.262712
#                        11       80.403642
#                        12       80.662338
# Griffin High School    9        83.369193
#                        10       83.706897
#                        11       84.288089
#                        12       84.013699
# Hernandez High School  9        80.866860
#                        10       80.660147
#                        11       81.396140
#                        12       80.857143
# Holden High School     9        83.677165
#                        10       83.324561
#                        11       83.815534
#                        12       84.698795
# Huang High School      9        81.290284
#                        10       81.512386
#                        11       81.417476
#                        12       80.305983
# Johnson High School    9        81.260714
#                        10       80.773431
#                        11       80.616027
#                        12       81.227564
# Pena High School       9        83.807273
#                        10       83.612000
#                        11       84.335938
#                        12       84.591160
# Rodriguez High School  9        80.993127
#                        10       80.629808
#                        11       80.864811
#                        12       80.376426
# Shelton High School    9        84.122642
#                        10       83.441964
#                        11       84.373786
#                        12       82.781671
# Thomas High School     9        83.728850
#                        10       84.254157
#                        11       83.585542
#                        12       83.831361
# Wilson High School     9        83.939778
#                        10       84.021452
#                        11       83.764608
#                        12       84.317673
# Wright High School     9        83.833333
#                        10       83.812757
#                        11       84.156322
#                        12       84.073171
# Name: reading_score, dtype: float64

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Sample bins. Feel free to create your own bins.
spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

# %%
(pd.cut(sch_d_cons_unf['Per Student Funding'],spending_bins,labels=group_names)).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-6834eae31432> in <module>()
# ----> 1 (pd.cut(sch_d_cons_unf['Per Student Funding'],spending_bins,labels=group_names)).head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     232                               include_lowest=include_lowest,
#     233                               dtype=dtype,
# --> 234                               duplicates=duplicates)
#     235
#     236     return _postprocess_for_cut(fac, bins, retbins, x_is_series,
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     335
#     336     side = 'left' if right else 'right'
# --> 337     ids = _ensure_int64(bins.searchsorted(x, side=side))
#     338
#     339     if include_lowest:
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Sample bins. Feel free to create your own bins.
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type.
